# %%
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split 
from tensorflow import keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint



x = np.load('x_train.npy')
y = np.load('y_train.npy')


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)



x_train = x_train.astype('float32')
x_test = x_test.astype('float32')


x_train = x_train / 255
x_test = x_test / 255



NUM_CLASSES = 11  
y_train = keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test = keras.utils.to_categorical(y_test, NUM_CLASSES)

model = keras.Sequential()

model.add(keras.layers.Conv2D(32, activation=tf.nn.relu, kernel_size=(3, 3), input_shape=x_train.shape[1:]))  
model.add(keras.layers.MaxPool2D(pool_size=(2, 2)))   
model.add(keras.layers.Dropout(0.25))                 

model.add(keras.layers.Conv2D(64, activation=tf.nn.relu,kernel_size=(3, 3)))
model.add(keras.layers.MaxPool2D(pool_size=(2, 2)))
model.add(keras.layers.Dropout(0.25))

model.add(keras.layers.Conv2D(128, activation=tf.nn.relu,kernel_size=(3, 3)))
model.add(keras.layers.MaxPool2D(pool_size=(2, 2)))
model.add(keras.layers.Dropout(0.25))

model.add(keras.layers.Conv2D(256, activation=tf.nn.relu,kernel_size=(3, 3)))
model.add(keras.layers.MaxPool2D(pool_size=(2, 2)))
model.add(keras.layers.Dropout(0.25))

model.add(keras.layers.Conv2D(512, activation=tf.nn.relu,kernel_size=(3, 3)))
model.add(keras.layers.MaxPool2D(pool_size=(2, 2)))
model.add(keras.layers.Dropout(0.25))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(550, activation=tf.nn.relu))  
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Dense(330, activation=tf.nn.relu))  
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Dense(110, activation=tf.nn.relu))  
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Dense(44, activation=tf.nn.relu))  
model.add(keras.layers.Dense(NUM_CLASSES, activation=tf.nn.softmax))
model.summary()



model.compile(optimizer=keras.optimizers.Adam(),
              loss='categorical_crossentropy',             
              metrics=['accuracy'])


filepath='weights.best.hdf5'


checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True,mode='max')
callbacks_list = [checkpoint]


history = model.fit(x_train, y_train, callbacks=callbacks_list, validation_data = (x_test, y_test),epochs=1000)
# Out:
# Using TensorFlow backend.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 174, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 87, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 127, 87, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 85, 64)       18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 42, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 62, 42, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 40, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 20, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 20, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 9, 256)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 9, 256)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 7, 512)        1180160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 3, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 550)               5069350
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 550)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 330)               181830
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 330)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 110)               36410
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 110)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 44)                4884
# _________________________________________________________________
# dense_4 (Dense)              (None, 11)                495
# =================================================================
# Total params: 6,861,545
# Trainable params: 6,861,545
# Non-trainable params: 0
# _________________________________________________________________
# Train on 460 samples, validate on 116 samples
# Epoch 1/1000
# 460/460 [==============================] - 46s 100ms/sample - loss: 2.2726 - accuracy: 0.1935 - val_loss: 2.3260 - val_accuracy: 0.1466
# C:\software\anaconda\lib\site-packages\keras\callbacks\callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# Epoch 2/1000
# 460/460 [==============================] - 44s 96ms/sample - loss: 2.2077 - accuracy: 0.2239 - val_loss: 2.2614 - val_accuracy: 0.1466
# Epoch 3/1000
# 460/460 [==============================] - 45s 99ms/sample - loss: 2.1732 - accuracy: 0.2261 - val_loss: 2.2386 - val_accuracy: 0.1466
# Epoch 4/1000
# 460/460 [==============================] - 48s 105ms/sample - loss: 2.0470 - accuracy: 0.2804 - val_loss: 2.0645 - val_accuracy: 0.2155
# Epoch 5/1000
# 460/460 [==============================] - 44s 96ms/sample - loss: 1.8379 - accuracy: 0.3283 - val_loss: 1.9654 - val_accuracy: 0.4224
# Epoch 6/1000
# 460/460 [==============================] - 45s 98ms/sample - loss: 1.6192 - accuracy: 0.4065 - val_loss: 1.8692 - val_accuracy: 0.4483
# Epoch 7/1000
# 460/460 [==============================] - 46s 101ms/sample - loss: 1.5006 - accuracy: 0.5043 - val_loss: 1.6155 - val_accuracy: 0.4741
# Epoch 8/1000
# 460/460 [==============================] - 41s 90ms/sample - loss: 1.4332 - accuracy: 0.4935 - val_loss: 1.6583 - val_accuracy: 0.4828
# Epoch 9/1000
# 460/460 [==============================] - 52s 114ms/sample - loss: 1.3725 - accuracy: 0.5348 - val_loss: 1.6427 - val_accuracy: 0.4741
# Epoch 10/1000
# 460/460 [==============================] - 44s 95ms/sample - loss: 1.1553 - accuracy: 0.6109 - val_loss: 1.3398 - val_accuracy: 0.5259
# Epoch 11/1000
# 460/460 [==============================] - 44s 97ms/sample - loss: 1.1081 - accuracy: 0.6587 - val_loss: 1.4306 - val_accuracy: 0.5431
# Epoch 12/1000
# 460/460 [==============================] - 47s 103ms/sample - loss: 0.9927 - accuracy: 0.6783 - val_loss: 1.2134 - val_accuracy: 0.5948
# Epoch 13/1000
# 460/460 [==============================] - 46s 100ms/sample - loss: 1.0661 - accuracy: 0.6804 - val_loss: 1.1215 - val_accuracy: 0.6121
# Epoch 14/1000
# 460/460 [==============================] - 43s 95ms/sample - loss: 0.9244 - accuracy: 0.7239 - val_loss: 1.0741 - val_accuracy: 0.6638
# Epoch 15/1000
# 460/460 [==============================] - 39s 85ms/sample - loss: 0.8838 - accuracy: 0.6978 - val_loss: 1.0255 - val_accuracy: 0.6552
# Epoch 16/1000
# 460/460 [==============================] - 47s 101ms/sample - loss: 0.8546 - accuracy: 0.7152 - val_loss: 1.0819 - val_accuracy: 0.6552
# Epoch 17/1000
# 460/460 [==============================] - 46s 99ms/sample - loss: 0.8262 - accuracy: 0.7261 - val_loss: 1.0721 - val_accuracy: 0.6552
# Epoch 18/1000
# 460/460 [==============================] - 44s 95ms/sample - loss: 0.7795 - accuracy: 0.7500 - val_loss: 1.0504 - val_accuracy: 0.6983
# Epoch 19/1000
# 460/460 [==============================] - 44s 96ms/sample - loss: 0.7070 - accuracy: 0.7696 - val_loss: 0.9410 - val_accuracy: 0.6983
# Epoch 20/1000
# 460/460 [==============================] - 46s 100ms/sample - loss: 0.5512 - accuracy: 0.8217 - val_loss: 0.9544 - val_accuracy: 0.7069
# Epoch 21/1000
# 460/460 [==============================] - 43s 94ms/sample - loss: 0.5425 - accuracy: 0.8174 - val_loss: 1.0106 - val_accuracy: 0.6983
# Epoch 22/1000
# 460/460 [==============================] - 48s 104ms/sample - loss: 0.5174 - accuracy: 0.8283 - val_loss: 0.9698 - val_accuracy: 0.6983
# Epoch 23/1000
# 460/460 [==============================] - 47s 102ms/sample - loss: 0.5720 - accuracy: 0.8087 - val_loss: 1.0382 - val_accuracy: 0.6810
# Epoch 24/1000
# 460/460 [==============================] - 42s 91ms/sample - loss: 0.5750 - accuracy: 0.8087 - val_loss: 1.0376 - val_accuracy: 0.6379
# Epoch 25/1000
# 460/460 [==============================] - 43s 94ms/sample - loss: 0.5021 - accuracy: 0.8283 - val_loss: 0.9082 - val_accuracy: 0.6897
# Epoch 26/1000
# 460/460 [==============================] - 40s 88ms/sample - loss: 0.4128 - accuracy: 0.8543 - val_loss: 0.8962 - val_accuracy: 0.7155
# Epoch 27/1000
# 460/460 [==============================] - 45s 97ms/sample - loss: 0.5781 - accuracy: 0.8174 - val_loss: 0.8625 - val_accuracy: 0.7155
# Epoch 28/1000
# 460/460 [==============================] - 45s 99ms/sample - loss: 0.4749 - accuracy: 0.8457 - val_loss: 1.0889 - val_accuracy: 0.6466
# Epoch 29/1000
# 460/460 [==============================] - 46s 100ms/sample - loss: 0.4464 - accuracy: 0.8261 - val_loss: 0.8633 - val_accuracy: 0.7414
# Epoch 30/1000
# 460/460 [==============================] - 44s 96ms/sample - loss: 0.3552 - accuracy: 0.8804 - val_loss: 0.8787 - val_accuracy: 0.7241
# Epoch 31/1000
# 460/460 [==============================] - 41s 89ms/sample - loss: 0.3686 - accuracy: 0.8783 - val_loss: 0.8006 - val_accuracy: 0.7500
# Epoch 32/1000
# 460/460 [==============================] - 45s 97ms/sample - loss: 0.3990 - accuracy: 0.8674 - val_loss: 0.8623 - val_accuracy: 0.7241
# Epoch 33/1000
# 460/460 [==============================] - 43s 94ms/sample - loss: 0.3920 - accuracy: 0.8739 - val_loss: 0.7514 - val_accuracy: 0.7500
# Epoch 34/1000
# 460/460 [==============================] - 43s 94ms/sample - loss: 0.2803 - accuracy: 0.8978 - val_loss: 0.6394 - val_accuracy: 0.8017
# Epoch 35/1000
# 460/460 [==============================] - 42s 92ms/sample - loss: 0.3530 - accuracy: 0.8848 - val_loss: 0.9306 - val_accuracy: 0.6897
# Epoch 36/1000
# 460/460 [==============================] - 41s 89ms/sample - loss: 0.2851 - accuracy: 0.8957 - val_loss: 0.7633 - val_accuracy: 0.7414
# Epoch 37/1000
# 460/460 [==============================] - 42s 92ms/sample - loss: 0.2333 - accuracy: 0.9217 - val_loss: 0.8572 - val_accuracy: 0.7586
# Epoch 38/1000
# 460/460 [==============================] - 42s 91ms/sample - loss: 0.2228 - accuracy: 0.9304 - val_loss: 0.7865 - val_accuracy: 0.7672
# Epoch 39/1000
# 460/460 [==============================] - 43s 94ms/sample - loss: 0.1675 - accuracy: 0.9457 - val_loss: 0.9084 - val_accuracy: 0.7759
# Epoch 40/1000
# 460/460 [==============================] - 41s 89ms/sample - loss: 0.1929 - accuracy: 0.9413 - val_loss: 0.9170 - val_accuracy: 0.7241
# Epoch 41/1000
# 460/460 [==============================] - 43s 93ms/sample - loss: 0.1982 - accuracy: 0.9283 - val_loss: 1.0618 - val_accuracy: 0.7586
# Epoch 42/1000
# 460/460 [==============================] - 44s 95ms/sample - loss: 0.2021 - accuracy: 0.9391 - val_loss: 0.8205 - val_accuracy: 0.7845
# Epoch 43/1000
# 460/460 [==============================] - 44s 95ms/sample - loss: 0.2332 - accuracy: 0.9283 - val_loss: 0.9169 - val_accuracy: 0.7414
# Epoch 44/1000
# 460/460 [==============================] - 50s 109ms/sample - loss: 0.1791 - accuracy: 0.9413 - val_loss: 0.9144 - val_accuracy: 0.7672
# Epoch 45/1000
# 460/460 [==============================] - 46s 100ms/sample - loss: 0.2451 - accuracy: 0.9196 - val_loss: 0.7319 - val_accuracy: 0.7672
# Epoch 46/1000
# 460/460 [==============================] - 50s 108ms/sample - loss: 0.1865 - accuracy: 0.9413 - val_loss: 0.7061 - val_accuracy: 0.7759
# Epoch 47/1000
# 460/460 [==============================] - 46s 100ms/sample - loss: 0.1792 - accuracy: 0.9435 - val_loss: 0.9845 - val_accuracy: 0.7241
# Epoch 48/1000
# 460/460 [==============================] - 43s 94ms/sample - loss: 0.1804 - accuracy: 0.9413 - val_loss: 0.8927 - val_accuracy: 0.7845
# Epoch 49/1000
# 460/460 [==============================] - 42s 91ms/sample - loss: 0.2811 - accuracy: 0.9152 - val_loss: 0.8267 - val_accuracy: 0.7759
# Epoch 50/1000
#  32/460 [=>............................] - ETA: 30s - loss: 0.2761 - accuracy: 0.9062
